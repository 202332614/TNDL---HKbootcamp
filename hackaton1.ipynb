# %%
# !npm init -y
# !npm install express
# Out:
# Wrote to /content/package.json:
#
# {
#   "name": "content",
#   "version": "1.0.0",
#   "main": "index.js",
#   "scripts": {
#     "test": "echo \"Error: no test specified\" && exit 1",
#     "start": "node server.js"
#   },
#   "keywords": [],
#   "author": "",
#   "license": "ISC",
#   "dependencies": {
#     "express": "^5.2.1"
#   },
#   "devDependencies": {},
#   "description": ""
# }
#
#
#
# ⠙⠙⠹⠸⠼⠴
# up to date, audited 66 packages in 1s
# ⠴
# ⠴22 packages are looking for funding
# ⠴  run `npm fund` for details
# ⠴
# found 0 vulnerabilities
# ⠴

# %%
# !mkdir -p /content/templates
# !mkdir -p /content/static

# %%
# %%writefile server.js
#
# const express = require("express");
# const path = require("path");
# const app = express();
# const PORT = 3000;
#
# // 핵심: static 폴더 안에 있는 파일들을 "/" 경로로 바로 접근할 수 있게 해줍니다.
# // 이렇게 하면 HTML에서 "/logo.png"라고만 써도 static 폴더를 찾아갑니다.
# app.use(express.static(path.join(__dirname, "static")));
#
# // 페이지 라우팅
# app.get("/", (req, res) => {
#   res.sendFile(path.join(__dirname, "templates", "home.html"));
# });
#
# app.get("/home", (req, res) => {
#   res.sendFile(path.join(__dirname, "templates", "home.html"));
# });
#
# app.get("/record", (req, res) => {
#   res.sendFile(path.join(__dirname, "templates", "record.html"));
# });
#
# app.get("/insight", (req, res) => {
#   res.sendFile(path.join(__dirname, "templates", "insight.html"));
# });
#
# // 이미지용 app.get("/card.png"...) 등등은 모두 삭제하세요! 위에서 이미 처리되었습니다.
#
# app.listen(PORT, function () {
#   console.log("==============================================");
#   console.log("소비 행동 분석 대시보드 배포 완료!");
#   console.log("접속 URL: http://localhost:" + PORT);
#   console.log("==============================================");
# });
# Out:
# Overwriting server.js

# %%
# !nohup node server.js > server.log 2>&1 &

# %%
# !npm install -g cloudflared
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏
# changed 1 package in 2s
# ⠏

# %%
# !nohup cloudflared tunnel --url http://localhost:3000 > tunnel.log 2>&1 &

# %%
# !tail -n 20 tunnel.log
# Out:
# 2026-03-12T13:46:42Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2026-03-12T13:46:55Z INF +--------------------------------------------------------------------------------------------+
# 2026-03-12T13:46:55Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# 2026-03-12T13:46:55Z INF |  https://berry-low-cage-competitive.trycloudflare.com                                      |
# 2026-03-12T13:46:55Z INF +--------------------------------------------------------------------------------------------+
# 2026-03-12T13:46:55Z INF Cannot determine default configuration path. No file [config.yml config.yaml] in [~/.cloudflared ~/.cloudflare-warp ~/cloudflare-warp /etc/cloudflared /usr/local/etc/cloudflared]
# 2026-03-12T13:46:55Z INF Version 2026.3.0 (Checksum 4a9e50e6d6d798e90fcd01933151a90bf7edd99a0a55c28ad18f2e16263a5c30)
# 2026-03-12T13:46:55Z INF GOOS: linux, GOVersion: go1.24.13, GoArch: amd64
# 2026-03-12T13:46:55Z INF Settings: map[ha-connections:1 protocol:quic url:http://localhost:3000]
# 2026-03-12T13:46:55Z INF Autoupdate frequency is set autoupdateFreq=86400000
# 2026-03-12T13:46:55Z INF Generated Connector ID: 00633de5-4dcb-406f-a7cf-c2fdf6f8c598
# 2026-03-12T13:46:55Z INF Initial protocol quic
# 2026-03-12T13:46:55Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-03-12T13:46:55Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026-03-12T13:46:55Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-03-12T13:46:55Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026-03-12T13:46:55Z INF Starting metrics server on 127.0.0.1:20243/metrics
# 2026-03-12T13:46:55Z INF Tunnel connection curve preferences: [X25519MLKEM768 CurveP256] connIndex=0 event=0 ip=198.41.200.193
# 2026/03/12 13:46:55 failed to sufficiently increase receive buffer size (was: 208 kiB, wanted: 7168 kiB, got: 416 kiB). See https://github.com/quic-go/quic-go/wiki/UDP-Buffer-Sizes for details.
# 2026-03-12T13:46:55Z INF Registered tunnel connection connIndex=0 connection=218f86b7-0f45-49e1-9a24-e02d663142b9 event=0 ip=198.41.200.193 location=sea07 protocol=quic

# %%
# !grep -o "https://[a-zA-Z0-9.-]*\.trycloudflare.com" tunnel.log |tail -n 1
# Out:
# https://berry-low-cage-competitive.trycloudflare.com
